# %%
import pstats

# %%
stats=pstats.Stats('../../profile.out')
stats.strip_dirs().sort_stats('cumulative').print_stats(20)
# Out:
# Thu Jul 17 15:11:10 2025    ../../profile.out
#
#          3627914 function calls (3568438 primitive calls) in 179.758 seconds
#
#    Ordered by: cumulative time
#    List reduced from 11431 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    3895/1    0.098    0.000  179.762  179.762 {built-in method builtins.exec}
#         1    0.000    0.000  179.762  179.762 genome_maze_trial.py:1(<module>)
#         1    0.000    0.000  175.186  175.186 genome_maze_trial.py:7(run_genome_exp)
#         5    0.000    0.000  175.161   35.032 genome_EA.py:53(evaluate)
#         5    0.000    0.000  171.227   34.245 genome_EA.py:66(<dictcomp>)
#        50    0.002    0.000  171.226    3.425 process.py:771(submit)
#        50    0.000    0.000  171.218    3.424 process.py:737(_adjust_process_count)
#        50    0.000    0.000  171.218    3.424 process.py:760(_spawn_process)
# ...

# %% [markdown]
# #### `snakeviz` Profiling
#
# `python -m cProfile -o profile_output.prof script.py`<br>
# `snakeviz profile_output.prof`
